# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.io import loadmat
from pandas import read_csv
from sklearn.decomposition import PCA

pine = pine = loadmat(r'C:\Users\Tutku\PycharmProjects\pythonProject24\Indian_pines (1).mat')['indian_pines']

#pine_gt[:40,:10]



#print(pine_gt)
pine_gt = pine.reshape((145*145, 220))

# %%
pca = PCA(n_components = 3)
pca.fit(pine_gt)
pine_gt_pca = pca.fit_transform(pine_gt)
pine_gt_pca.shape
# Out:
# (21025, 3)

# %%
pine_gt_pca.shape
pca.fit_transform(pine_gt)
# Out:
# array([[ 5014.88994002,  1456.88249524,    72.76422084],
#        [ 5601.36588022, -2023.43369375,   350.19032289],
#        [ 5796.14487388, -3090.38340858,   490.55915965],
#        ...,
#        [-7369.84017524, -1132.38668253,   398.17651525],
#        [-6497.10049748,   798.24538296,   676.84402131],
#        [-6570.48578562,   346.75571506,   465.51150753]])

# %%
resim = pine_gt_pca.reshape((145, 145, 3))
plt.imshow(resim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#resim2 = pine_gt_pca.reshape((145, 145, 3))
plt.imshow(pine_gt_pca)
