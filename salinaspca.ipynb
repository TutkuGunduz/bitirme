# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.io import loadmat
from pandas import read_csv
from sklearn.decomposition import PCA

salinas = loadmat(r'C:\Users\Tutku\PycharmProjects\pythonProject24\Salinas.mat')['salinas']


salinasre = salinas.reshape((512*217, 224))

# %%
pca = PCA(n_components = 3)
pca.fit(salinasre)
salinasre_pca = pca.fit_transform(salinasre)
salinasre_pca.shape
# Out:
# (111104, 3)

# %%
salinasre_pca.shape
pca.fit_transform(salinasre)
# Out:
# array([[-6136.37278499, -4385.71385938,   628.4074287 ],
#        [-6196.94917017, -4360.64584141,   568.28059334],
#        [-6359.50363249, -4693.93957787,   578.03104286],
#        ...,
#        [-6740.48686494, -4127.19798479,   595.00797135],
#        [-6763.52778187, -4135.19798822,   579.1823551 ],
#        [-6664.08486037, -4017.92051011,   583.41972121]])

# %%
resim = salinasre_pca.reshape((512, 217, 3))
plt.imshow(resim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
